# %% [markdown]
# <a href="https://colab.research.google.com/github/ramabhinav2001/ML_HW2/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read and load data from given non-linear data values
data = pd.read_csv("/content/HW2_nonlinear_data.csv")
X = data['X'].values
Y = data['Y'].values
plt.scatter(X,Y)
plt.show()

# %%
# Defining cubic function
def cubic_function(X, a, b, c, d):
    return a * X**3 + b * X**2 + c * X + d
# Define mean square error(MSE) loss function
def mse_loss(Y_true, Y_pred):
    return np.mean((Y_true - Y_pred)**2)
# Initializing parameters
a, b, c, d = np.random.rand(4)  # Random initialization
L= 1e-6
epochs = 10000
# Performing gradient descent to optimize the parameters
for epoch in range(epochs):
    # Calculate predictions
    y_pred = cubic_function(X, a, b, c, d)

    # Calculate the gradient of the loss with respect to each parameter
    grad_a = -2 * np.mean((Y - y_pred) * X**3)
    grad_b = -2 * np.mean((Y - y_pred) * X**2)
    grad_c = -2 * np.mean((Y - y_pred) * X)
    grad_d = -2 * np.mean(Y - y_pred)

    # Update the parameters
    a -= L * grad_a
    b -= L * grad_b
    c -= L * grad_c
    d -= L * grad_d

    # Calculate the current loss
    curr_lost = mse_loss(Y, y_pred)

    if epoch % 1000 == 0:
        print(f"Epoch {epoch}: Loss = {curr_lost:.6f}")

print("Training completed.")

# Print the optimized parameters
print(f"Optimized parameters: a = {a}, b = {b}, c = {c}, d = {d}")

# Plot the data and the fitted cubic function using given cubic equation
plt.scatter(X, Y, label="Data")
y_pred = cubic_function(X, a, b, c, d)
plt.scatter(X, y_pred, color='red', label="Cubic Function")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Non-linear Regression")
plt.show()
# Out:
# Epoch 0: Loss = 15322990.593258
# Epoch 1000: Loss = 593539.591776
# Epoch 2000: Loss = 592255.366502
# Epoch 3000: Loss = 591631.114572
# Epoch 4000: Loss = 591009.439164
# Epoch 5000: Loss = 590389.691430
# Epoch 6000: Loss = 589771.852056
# Epoch 7000: Loss = 589155.902655
# Epoch 8000: Loss = 588541.825153
# Epoch 9000: Loss = 587929.601787
# Training completed.
# Optimized parameters: a = 10.645683424727006, b = 20.97232278979074, c = -1.1662603741042472, d = 8.03268641295899
